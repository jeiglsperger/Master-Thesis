# %%
from evaluate_cashierdata import test_samples
test_samples("CTGAN_noshift", print_data=True)
# Out:
#      CutFlowers   PotOwn  PotPurchased  Wholesale  FruitsVegs  Commodity  \
# 0      559.9682 247.3959       43.8499     0.1223     56.5742    81.9888
# 1      117.7601   0.0000        0.0000     0.0000      0.0000    28.3715
# 2      170.0639   3.4445       12.4611     0.0000      0.7525     2.4854
# 3      119.4458 180.6914        2.8437   329.7793     21.4661    22.0203
# 4      109.1586 102.5677       33.4883     0.0000      8.4186    60.7036
# ..          ...      ...           ...        ...         ...        ...
# 495      0.0000   0.0000        0.0000     0.0000     33.6933    17.7937
# 496    193.1139 174.9459      107.3777     0.4903     27.2292    56.8913
# 497    436.0060 101.1024       12.7145   148.1263     15.0802    99.6397
# 498    236.4983 356.0432      167.2146   117.3022     40.9638   181.9298
# 499    372.5193 571.1273       16.4106     2.0916      8.0132   201.1942
#
#      mean_temp  mean_humid  mean_prec_height_mm  total_prec_height_mm  \
# ...
