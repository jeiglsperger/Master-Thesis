# 0  2049  13384  4328  5928  3128  29726        1651006
# 1  2066  12158  4407  4595  3157  34460        2319088
# 2  2142  12810  5019  4814  2977  34875        2279706
# 3  2185  13636  4754  5964  2918  29160        1565291
# 4  2060  14724  4679  6717  3328  33808        1773996
# 5  2167  13288  4846  5073  3369  37350        2408140
# 6  2252  14055  5657  5246  3152  40317        2500453
# 7  2251  14911  5176  6592  3143  32432        1664034
# 8  2139  15882  5017  7272  3593  38480        1989797
# 9  2227  14150  5207  5217  3727  42917        2641323
# Correlation metric: pearsonr
#
# Regressor MSE-scores and their Jaccard similarities:
#                                           real           fake
# real_data_RandomForestRegressor   219,588.6705 2,266,383.1238
# real_data_Lasso                    73,719.3705 3,490,285.2642
# real_data_Ridge                    58,460.8277   696,978.8004
# real_data_ElasticNet               73,627.7297 3,487,691.8995
# fake_data_RandomForestRegressor 1,358,770.3084 1,174,011.2847
# fake_data_Lasso                   521,805.4546 2,383,012.2917
# fake_data_Ridge                 1,345,659.7749   898,595.6054
# fake_data_ElasticNet              521,805.4788 2,383,012.0149
#
# Miscellaneous results:
#                                          Result
# Column Correlation Distance RMSE         0.7680
# Column Correlation distance MAE          0.6528
# Duplicate rows between sets (real/fake)  (0, 0)
# nearest neighbor mean                    6.8495
# nearest neighbor std                     1.0179
#
# Results:
#                                                 Result
# Basic statistics                                0.6938
# Correlation column correlations                 0.0135
# Mean Correlation between fake and real columns  0.8645
# Correlation RMSE                               -0.5785
# Similarity Score                                0.2483
#                     metric                                     name  \
# 1        LogisticDetection             LogisticRegression Detection
# 2             SVCDetection                            SVC Detection
# 11         GMLogLikelihood           GaussianMixture Log Likelihood
# 13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
# 14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
# 27  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
#
#                    raw_score  normalized_score  min_value  max_value      goal
# 1                     0.0000            0.0000     0.0000     1.0000  MAXIMIZE
# 2                     0.0000            0.0000     0.0000     1.0000  MAXIMIZE
# 11 -979,010,705,727,179.3750            0.0000       -inf        inf  MAXIMIZE
# 13                    0.3663            0.3663     0.0000     1.0000  MAXIMIZE
# 14                    0.3663            0.3663     0.0000     1.0000  MAXIMIZE
# 27                    0.1065            0.1065     0.0000     1.0000  MAXIMIZE

# %%
import matplotlib.pyplot as plt
import optuna
study = optuna.load_study(study_name="CTGAN_touristsindia_noshift_study", storage="sqlite:///CTGAN_touristsindia_noshift.db")
fig1 = optuna.visualization.matplotlib.plot_optimization_history(study)
# fig2 = optuna.visualization.matplotlib.plot_intermediate_values(study)  # That's for pruning
fig3 = optuna.visualization.matplotlib.plot_parallel_coordinate(study)
fig4 = optuna.visualization.matplotlib.plot_contour(study)
fig5 = optuna.visualization.matplotlib.plot_slice(study)
fig6 = optuna.visualization.matplotlib.plot_param_importances(study)
fig7 = optuna.visualization.matplotlib.plot_edf(study)
plt.show()
# Out:
# [W 2021-12-15 06:20:53,745] Output figures of this Matplotlib-based `plot_contour` function would be different from those of the Plotly-based `plot_contour`.
