# %%
from evaluate import test_samples
# %load_ext autoreload
# %autoreload
test_samples("Schachtschneider_externals_cut.csv", database_name="CTGAN_schacht", print_data=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# Correlation metric: pearsonr
#
# Regressor MSE-scores and their Jaccard similarities:
#                                     real     fake
# real_data_RandomForestRegressor  58.7852 572.5850
# real_data_Lasso                  14.0533 681.1928
# real_data_Ridge                  74.7994 831.6592
# real_data_ElasticNet             18.7188 666.0138
# fake_data_RandomForestRegressor  45.3888 576.3842
# fake_data_Lasso                  59.7679 594.4720
# fake_data_Ridge                 275.5735  17.7712
# fake_data_ElasticNet             55.8992 582.8034
#
# Miscellaneous results:
#                                           Result
# Column Correlation Distance RMSE          0.7438
# Column Correlation distance MAE           0.6801
# Duplicate rows between sets (real/fake)   (0, 0)
# nearest neighbor mean                   155.3828
# nearest neighbor std                    227.8508
#
# Results:
# ...
