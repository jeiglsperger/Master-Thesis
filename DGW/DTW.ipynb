# %%
from DTW import run_DTW
# %load_ext autoreload
# %autoreload
run_DTW(50, "noshift", 0)
# Out:
# [I 2021-10-30 09:28:46,795] A new study created in RDB with name: no-name-ba4a512c-37ba-474b-a341-8f9fc4786ca1
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:01<00:00, 421.37it/s]
# (0,)
# [I 2021-10-30 09:29:00,337] Trial 0 finished with value: 0.1341378939625003 and parameters: {'batch_size': 4, 'slope_constraint': 'symmetric', 'use_window': 'False', 'dtw_type': 'normal', 'use_variable_slice': 'False'}. Best is trial 0 with value: 0.1341378939625003.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:30<00:00, 26.34it/s]
# (0,)
# ...
