# %%
from DTW import run_DTW
# %load_ext autoreload
# %autoreload
run_DTW(50, "noshift", 0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [I 2021-11-04 13:35:39,700] A new study created in RDB with name: no-name-563d5265-21e7-44a9-bfdb-a7e4c1d3eebc
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:12<00:00, 65.20it/s]
# [I 2021-11-04 13:36:04,738] Trial 0 finished with value: 0.13431531307737818 and parameters: {'batch_size': 12, 'slope_constraint': 'symmetric', 'use_window': 'True', 'dtw_type': 'normal', 'use_variable_slice': 'True'}. Best is trial 0 with value: 0.13431531307737818.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:06<00:00, 132.77it/s]
# ...
