# %%
from DTW import run_DTW
run_DTW(50, "noshift", 0)
# Out:
# [I 2021-11-04 17:05:11,258] A new study created in RDB with name: no-name-b4830906-9eaf-4bfc-84c8-59f509beb0da
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:19<00:00, 41.89it/s]
# [I 2021-11-04 17:05:43,666] Trial 0 finished with value: 0.13330393687591527 and parameters: {'batch_size': 8, 'slope_constraint': 'symmetric', 'use_window': 'False', 'dtw_type': 'shape', 'use_variable_slice': 'True'}. Best is trial 0 with value: 0.13330393687591527.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:02<00:00, 393.41it/s]
# ...
