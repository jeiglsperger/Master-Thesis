# %%
import pandas as pd
df = pd.read_csv("fake_data_schachtschneider_noshift.csv")
df = df.fillna(0)
df.to_csv("fake_data_schachtschneider_noshift.csv", index=False)
from DGW_cashierdata import run_DTW
run_DTW(50, "noshift", 0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [I 2021-11-06 15:02:52,195] A new study created in RDB with name: no-name-a55c8d2a-3eb6-4b8f-9324-3cc5200691ac
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:05<00:00, 152.94it/s]
# [I 2021-11-06 15:03:10,005] Trial 0 finished with value: 0.13355664122555413 and parameters: {'batch_size': 4, 'slope_constraint': 'symmetric', 'use_window': 'True', 'dtw_type': 'shape', 'use_variable_slice': 'True'}. Best is trial 0 with value: 0.13355664122555413.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 815/815 [00:02<00:00, 391.36it/s]
# ...
