# %%
from evaluate_cashierdata import test_samples
test_samples("noshift", print_data=True)
# Out:
#       CutFlowers   PotOwn  PotPurchased  Wholesale  FruitsVegs  Commodity  \
# 0         0.0000   0.0000        0.0000     0.0000      0.0000   609.0735
# 1         5.0853 185.8937        9.5233   136.9302      3.0419   574.4790
# 2       140.0000  79.8372       27.2966    18.9448      8.5454   147.6706
# 3       126.9000   5.0488       52.4884    36.8964      4.9744   126.6763
# 4         0.0000 277.5587       23.0529   327.2304     39.0651   535.3941
# ...          ...      ...           ...        ...         ...        ...
# 1082    958.5000  38.1349      179.8372   126.4154      4.1814   416.8842
# 1083    660.7800  26.2898       37.0000    26.0089     13.1930   330.1507
# 1084      0.0000   0.0000        0.0000     0.0000      0.0000     0.0000
# 1085    105.5000  60.1630       20.5699     0.0000      9.4618    80.7549
# 1086  1,793.0468  71.3381      133.2057   258.3735     19.8078 1,407.6949
#
#       mean_temp  mean_humid  mean_prec_height_mm  total_prec_height_mm  \
# ...
