# %%
from evaluate_cashierdata import test_samples
test_samples("timeGAN_shift1", print_data=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Out:
#        CutFlowers  PotOwn  PotPurchased  Wholesale  FruitsVegs  Commodity  \
# 0        290.6615 32.4909       43.3512     0.0317     13.8972    17.6520
# 1        157.3006 28.2255       13.8445     0.0100      8.8947     6.0865
# 2         22.7897 11.6561       15.2230     0.0212     25.1115    10.5560
# 3        372.5985 81.0832       44.5015     0.1837     40.7581    16.9436
# 4        102.3859 17.5211       12.3400     0.0111      5.9611     8.3010
# ...           ...     ...           ...        ...         ...        ...
# 31705    244.2712 16.1318       38.0139     0.0429      4.6725    14.8479
# 31706     13.1434  7.5813        6.0745     1.3561      3.9284     0.7529
# 31707    385.4503 27.7347       12.7310    11.5733      3.0737     1.7357
# 31708    248.8906 17.7365       32.2885     0.7534     13.7302    41.5174
# 31709    250.8775 21.5097       30.8411     4.4902     12.7101     6.8456
#
#        mean_temp  mean_humid  mean_prec_height_mm  total_prec_height_mm  \
# ...
