# %%
from evaluate import test_samples
# %load_ext autoreload
# %autoreload
test_samples("Public_QuarterlyTouristsIndia.csv", database_name="timeGAN_india", print_data=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_54005/3878681528.py in <module>
#       2 get_ipython().run_line_magic('load_ext', 'autoreload')
#       3 get_ipython().run_line_magic('autoreload', '')
# ----> 4 test_samples("Public_QuarterlyTouristsIndia.csv", database_name="timeGAN_india", print_data=False)
#
# /Josef/Master-Thesis/timeGAN/evaluate.py in test_samples(data, database_name, print_data)
#      15     """
#      16     # loads test and fake data
# ---> 17     test, fake = load_data('test_data_' + data, 'fake_data_' + database_name + '.csv')
#      18
#      19     # prints test and real data if flag print_data is set to true
#
# ...
